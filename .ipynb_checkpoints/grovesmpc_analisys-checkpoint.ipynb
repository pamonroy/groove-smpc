# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import pyxdf as xdf
import seaborn as sb

# %%
def select_lsl_stream(stream_name, streams):
    # Extract streams
    #  monogen: all variables at 8 Hz
    #  markers: Important events
    #  status : all variables on every important event (marker)
    #  kinect : XYZ pose coordinates at 60 Hz
    stream_list = streams[0]  
    for stream in stream_list:
        if stream['info']['name'][0] ==  stream_name:  
            return stream['time_series'], stream['time_stamps'], stream['info']['effective_srate']            
    return False

# %%
import glob

columns = ['density', 'evenness', 'syncopation', 'swing', 'cursor_position', 'bangBack', 'S_kick-snare', 'encuesta', 'valorA', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'momento_significativo', 'kick-snare', 'knob_start_value', 'trainorexperiment', 'valence', 'urgetomove']
df_all = pd.DataFrame(columns = columns)
df_all['participant'] = ''

for xdf_file in glob.glob("data/*.xdf"): 
    streams = xdf.load_xdf(xdf_file)
    status_time_series, status_timestamps, status_sample_rate = select_lsl_stream('status', streams)
    df = pd.DataFrame(status_time_series, columns = columns)
    df_out = df.loc[df['momento_significativo'] == 2]
    df_out['participant'] = xdf_file
    df_all = pd.concat([df_all, df_out])
    print(xdf_file)
    
columns_selected = ['evenness', 'syncopation', 'swing', 'valence', 'urgetomove']    
df = df_all[columns_selected]
# Out:
# Stream 3: Calculated effective sampling rate 53.1472 Hz is different from specified rate 60.0000 Hz.
# <ipython-input-3-3ae1e453c179>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_out['participant'] = xdf_file
# data/P09.xdf
# data/P08.xdf
# data/P05.xdf
# data/P10.xdf
# data/P04.xdf
# data/P06.xdf
# Stream 3: Calculated effective sampling rate 6.1893 Hz is different from specified rate 8.0000 Hz.
# data/P07.xdf
# data/P03.xdf
# data/P02.xdf
# data/P01.xdf

# %%
df = df.astype({'urgetomove':'int', 'valence':'int'}) 
df
# Out:
#     evenness  syncopation   swing  valence  urgetomove
# 3      0.675        0.650  69.375        5           3
# 7      0.450        0.400  54.375        3           3
# 11     0.775        0.350  58.125        6           5
# 15     0.275        1.000  70.625        3           3
# 21     0.750        0.875  69.375        4           4
# ..       ...          ...     ...      ...         ...
# 31     0.000        0.125  50.000        3           6
# 35     0.125        0.125  53.125        4           6
# 39     0.725        0.525  64.375        7           7
# 45     0.300        0.875  69.375        7           6
# 49     0.625        0.675  69.375        4           7
#
# [115 rows x 5 columns]

# %%
df.describe()
# Out:
#          evenness  syncopation       swing     valence  urgetomove
# count  115.000000   115.000000  115.000000  115.000000  115.000000
# mean     0.537609     0.556087   63.315216    4.886957    4.895652
# std      0.200640     0.259461    7.055628    1.620944    1.773953
# min      0.000000     0.000000   50.000000    1.000000    1.000000
# 25%      0.412500     0.400000   58.125000    4.000000    3.000000
# 50%      0.500000     0.550000   62.500000    5.000000    5.000000
# 75%      0.675000     0.787500   69.375000    6.000000    6.000000
# max      1.000000     1.000000   75.000000    7.000000    7.000000

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_a5c16_row0_col0, #T_a5c16_row1_col1, #T_a5c16_row2_col2, #T_a5c16_row3_col3, #T_a5c16_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a5c16_row0_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_a5c16_row0_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_a5c16_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_a5c16_row0_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_a5c16_row1_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_a5c16_row1_col2, #T_a5c16_row1_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_a5c16_row1_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_a5c16_row2_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_a5c16_row2_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a5c16_row2_col3, #T_a5c16_row2_col4, #T_a5c16_row4_col0, #T_a5c16_row4_col1, #T_a5c16_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a5c16_row3_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_a5c16_row3_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_a5c16_row3_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_a5c16_row3_col4 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_a5c16_row4_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a5c16_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >evenness</th>
#       <th class="col_heading level0 col1" >syncopation</th>
#       <th class="col_heading level0 col2" >swing</th>
#       <th class="col_heading level0 col3" >valence</th>
#       <th class="col_heading level0 col4" >urgetomove</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5c16_level0_row0" class="row_heading level0 row0" >evenness</th>
#       <td id="T_a5c16_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_a5c16_row0_col1" class="data row0 col1" >0.27</td>
#       <td id="T_a5c16_row0_col2" class="data row0 col2" >0.29</td>
#       <td id="T_a5c16_row0_col3" class="data row0 col3" >0.08</td>
#       <td id="T_a5c16_row0_col4" class="data row0 col4" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_a5c16_level0_row1" class="row_heading level0 row1" >syncopation</th>
#       <td id="T_a5c16_row1_col0" class="data row1 col0" >0.27</td>
#       <td id="T_a5c16_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_a5c16_row1_col2" class="data row1 col2" >0.02</td>
#       <td id="T_a5c16_row1_col3" class="data row1 col3" >0.10</td>
#       <td id="T_a5c16_row1_col4" class="data row1 col4" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_a5c16_level0_row2" class="row_heading level0 row2" >swing</th>
#       <td id="T_a5c16_row2_col0" class="data row2 col0" >0.29</td>
#       <td id="T_a5c16_row2_col1" class="data row2 col1" >0.02</td>
#       <td id="T_a5c16_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_a5c16_row2_col3" class="data row2 col3" >0.02</td>
#       <td id="T_a5c16_row2_col4" class="data row2 col4" >-0.06</td>
#     </tr>
#     <tr>
#       <th id="T_a5c16_level0_row3" class="row_heading level0 row3" >valence</th>
#       <td id="T_a5c16_row3_col0" class="data row3 col0" >0.08</td>
#       <td id="T_a5c16_row3_col1" class="data row3 col1" >0.10</td>
#       <td id="T_a5c16_row3_col2" class="data row3 col2" >0.02</td>
#       <td id="T_a5c16_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_a5c16_row3_col4" class="data row3 col4" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_a5c16_level0_row4" class="row_heading level0 row4" >urgetomove</th>
#       <td id="T_a5c16_row4_col0" class="data row4 col0" >0.07</td>
#       <td id="T_a5c16_row4_col1" class="data row4 col1" >-0.02</td>
#       <td id="T_a5c16_row4_col2" class="data row4 col2" >-0.06</td>
#       <td id="T_a5c16_row4_col3" class="data row4 col3" >0.85</td>
#       <td id="T_a5c16_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
sb.pairplot(df)

# %%
dfu=df.drop(columns=["valence"])
sb.pairplot(dfu, hue='urgetomove')

# %%
dfv=df.drop(columns=["urgetomove"])
sb.pairplot(dfv, hue='valence')

# %%
#plt.figure(figsize=(15,7))
sb.boxplot(y="evenness", x="urgetomove", data=df)
# Out:
# <AxesSubplot:xlabel='urgetomove', ylabel='evenness'>

# %%
sb.boxplot(y="syncopation", x="urgetomove", data=df)
# Out:
# <AxesSubplot:xlabel='urgetomove', ylabel='syncopation'>

# %%
sb.boxplot(y="swing", x="urgetomove", data=df)
# Out:
# <AxesSubplot:xlabel='urgetomove', ylabel='swing'>

# %%
sb.boxplot(y="evenness", x="valence", data=df)
# Out:
# <AxesSubplot:xlabel='valence', ylabel='evenness'>

# %%
sb.boxplot(y="syncopation", x="valence", data=df)
# Out:
# <AxesSubplot:xlabel='valence', ylabel='syncopation'>

# %%
sb.boxplot(y="swing", x="valence", data=df)
# Out:
# <AxesSubplot:xlabel='valence', ylabel='swing'>
